# %% [markdown]
# # Evaluation

# %%
import pickle
import os
import pandas as pd
import numpy as np
import sys

sys.path.append("../")
from src.data.make_dataset import INDEX_SHEET_NAME
from src.visualization.visualize import get_pivot_table

# %%
INDEX_SHEET_NAME
# Out:
# ['HangSeng Index Data',
#  'S&P500 Index Data',
#  'CSI300 Index Data',
#  'DJIA index Data',
#  'Nikkei 225 index Data',
#  'Nifty 50 index Data']

# %% [markdown]
# ### HangSeng Index

# %%
get_pivot_table(INDEX_SHEET_NAME[0])
# Out:
#              MAPE                                       R                      \
# Model        LSTM  SAE-LSTM     WLSTM WSAE-LSTM      LSTM  SAE-LSTM     WLSTM
# Year
# 2010     0.086896  0.056786  0.069749  0.096032  0.760126  0.844993  0.554282
# 2011     0.491565  0.431415  0.493953  0.330146  0.607038  0.725978  0.624373
# 2012     0.145721  0.072388  0.100982  0.080312  0.729085  0.887842  0.907004
# 2013     0.069845  0.068532  0.053192  0.064959  0.787206  0.805672  0.816690
# 2014     0.131523  0.161679  0.090556  0.071937  0.477127  0.249293  0.781152
# 2015     0.495276  0.416135  0.293988  0.224779  0.426716  0.721255  0.351967
# Average  0.236804  0.201156  0.183736  0.144694  0.631216  0.705839  0.672578
#
#                     Theil U
# Model   WSAE-LSTM      LSTM  SAE-LSTM     WLSTM WSAE-LSTM
# Year
# 2010     0.474885  0.048194  0.032497  0.041617  0.055152
# 2011     0.669505  0.134206  0.135803  0.135453  0.116304
# ...

# %% [markdown]
# ### Nikkei 225 index

# %%
get_pivot_table(INDEX_SHEET_NAME[-2])
# Out:
#               MAPE                                       R            \
# Model         LSTM  SAE-LSTM     WLSTM WSAE-LSTM      LSTM  SAE-LSTM
# Year
# 2010      0.028652  0.069302  0.040810  0.031154  0.969043  0.959430
# 2011     27.474453  6.870573  8.025787  0.302017  0.811278  0.883388
# 2012      0.326005  0.482594  0.958244  1.259117  0.914811  0.938460
# 2013      0.259648  0.274029  0.257867  0.278055  0.679032  0.627351
# 2014      0.112461  0.104462  0.125964  0.086409  0.774478  0.538003
# 2015      0.103384  0.092176  0.116772  0.105522  0.710025  0.827188
# Average   4.717434  1.315523  1.587574  0.343712  0.809778  0.795637
#
#                               Theil U
# Model       WLSTM WSAE-LSTM      LSTM  SAE-LSTM     WLSTM WSAE-LSTM
# Year
# 2010     0.967820  0.964688  0.017152  0.035517  0.023922  0.019143
# 2011     0.771340  0.896359  0.269030  0.249602  0.231803  0.121132
# 2012     0.924149  0.942136  0.076352  0.079090  0.109233  0.077901
# ...

# %% [markdown]
# ### S&P500 Index

# %%
get_pivot_table(INDEX_SHEET_NAME[1])
# Out:
#              MAPE                                       R                      \
# Model        LSTM  SAE-LSTM     WLSTM WSAE-LSTM      LSTM  SAE-LSTM     WLSTM
# Year
# 2010     0.044619  0.039788  0.035421  0.079107  0.834117  0.696632  0.806412
# 2011     0.132257  0.113349  0.098213  0.057782  0.471972  0.590470  0.599391
# 2012     0.076269  0.080527  0.056441  0.126443  0.624770  0.833748  0.752405
# 2013     0.155924  0.145965  0.117774  0.093531  0.263329  0.811349  0.715428
# 2014     0.139919  0.194393  0.115413  0.152029  0.454068  0.235128  0.680816
# 2015     0.105840  0.113391  0.122223  0.214861  0.360730  0.276745  0.388040
# Average  0.109138  0.114569  0.090914  0.120625  0.501498  0.574012  0.657082
#
#                     Theil U
# Model   WSAE-LSTM      LSTM  SAE-LSTM     WLSTM WSAE-LSTM
# Year
# 2010     0.221203  0.030925  0.026381  0.024463  0.052224
# 2011     0.807275  0.080306  0.061183  0.055797  0.032671
# ...

# %% [markdown]
# ### DJIA index

# %%
get_pivot_table(INDEX_SHEET_NAME[3])
# Out:
#              MAPE                                       R                      \
# Model        LSTM  SAE-LSTM     WLSTM WSAE-LSTM      LSTM  SAE-LSTM     WLSTM
# Year
# 2010     0.016065  0.022199  0.035034  0.028511  0.972682  0.764661  0.896327
# 2011     0.071240  0.126834  0.074710  0.072227  0.787065  0.523451  0.691303
# 2012     0.023427  0.085937  0.035418  0.071454  0.975379  0.904956  0.886702
# 2013     0.079384  0.097193  0.083292  0.069832  0.932337  0.722771  0.843031
# 2014     0.067333  0.119385  0.068672  0.063881  0.934848  0.503319  0.817133
# 2015     0.074116  0.137237  0.092175  0.082928  0.718401  0.749573  0.634567
# Average  0.055261  0.098131  0.064884  0.064806  0.886785  0.694789  0.794844
#
#                     Theil U
# Model   WSAE-LSTM      LSTM  SAE-LSTM     WLSTM WSAE-LSTM
# Year
# 2010     0.934353  0.009543  0.012992  0.020124  0.016095
# 2011     0.772014  0.043852  0.088054  0.043902  0.042503
# ...

# %% [markdown]
# ### CSI300 Index

# %%
get_pivot_table(INDEX_SHEET_NAME[2])
# Out:
#              MAPE                                         R            \
# Model        LSTM  SAE-LSTM      WLSTM  WSAE-LSTM      LSTM  SAE-LSTM
# Year
# 2010     0.042369  0.075944   0.066456   0.083372  0.914155  0.771516
# 2011     0.237833  0.499027   0.248391   0.286807  0.951613  0.813737
# 2012     8.315818  3.638219  17.035686  10.565861  0.940482  0.867435
# 2013     0.187829  0.132098   0.166706   0.164828  0.916640  0.889479
# 2014     0.557412  0.760077   0.448690   1.668902  0.952202  0.967628
# 2015     0.311599  0.333969   0.333118   0.338291  0.631318  0.284567
# Average  1.608810  0.906556   3.049841   2.184677  0.884402  0.765727
#
#                               Theil U
# Model       WLSTM WSAE-LSTM      LSTM  SAE-LSTM     WLSTM WSAE-LSTM
# Year
# 2010     0.816981  0.289518  0.027889  0.050275  0.046669  0.052479
# 2011     0.919988  0.882851  0.067304  0.087824  0.099692  0.112751
# 2012     0.839137  0.856014  0.263548  0.292629  0.358681  0.317800
# ...

# %% [markdown]
# ### Nifty 50

# %%
get_pivot_table(INDEX_SHEET_NAME[-1])
# Out:
#              MAPE                                       R                      \
# Model        LSTM  SAE-LSTM     WLSTM WSAE-LSTM      LSTM  SAE-LSTM     WLSTM
# Year
# 2010     0.052212  0.085186  0.082210  0.135106  0.885676  0.933870  0.765041
# 2011     0.060680  0.165775  0.050960  0.099899  0.919604  0.737480  0.882064
# 2012     0.082595  0.128930  0.117077  0.118235  0.952107  0.890573  0.937947
# 2013     0.081158  0.091237  0.075941  0.072090  0.873797  0.873103  0.747561
# 2014     0.191430  0.176181  0.168564  0.167403  0.648516  0.809012  0.614533
# 2015     0.088768  0.131177  0.069420  0.075120  0.827962  0.506880  0.743659
# Average  0.092807  0.129748  0.094029  0.111309  0.851277  0.791820  0.781801
#
#                     Theil U
# Model   WSAE-LSTM      LSTM  SAE-LSTM     WLSTM WSAE-LSTM
# Year
# 2010     0.607244  0.028300  0.045552  0.044913  0.074646
# 2011     0.689562  0.033080  0.073179  0.030304  0.055549
# ...
